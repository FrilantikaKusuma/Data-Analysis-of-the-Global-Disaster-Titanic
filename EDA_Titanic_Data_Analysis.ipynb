# %% [markdown]
# ## Titanic Sample Data Analysis
# By: Frilantika Kusuma Wardani
#
# # By this project, I will analyze the sample datasets of Titanic passengers within 500 entries data. In this analysis, I will be using Exploratory and Explanatory Analysis, here is the steps:
#
# 1. Explore the datasets with head, tail, sample and info to get a general review
# 2. Observe the datasets to get the summary statistical in order to explain info the data sample
# 3. Find the duplicate entries and how to solve it
# 4. Determine the missing value and check its percentages and how to manipulate to filled the missing entries

# %% [markdown]
# ## Import Libraries

# %%
#In this project I will use the Pandas for importing the dataset.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
# importing datasets
df = pd.read_excel('titanic.xlsx')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#      survived                                               name     sex  \
# 0           1                      Allen, Miss. Elisabeth Walton  female
# 1           1                     Allison, Master. Hudson Trevor    male
# 2           0                       Allison, Miss. Helen Loraine  female
# 3           0               Allison, Mr. Hudson Joshua Creighton    male
# 4           0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5           1                                Anderson, Mr. Harry    male
# 6           1                  Andrews, Miss. Kornelia Theodosia  female
# 7           0                             Andrews, Mr. Thomas Jr    male
# 8           1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9           0                            Artagaveytia, Mr. Ramon    male
# 10          0                             Astor, Col. John Jacob    male
# 11          1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# ...

# %%
# showing top 5 rows of data entries
df.head()
# Out:
#    survived                                             name     sex      age
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         0                     Allison, Miss. Helen Loraine  female   2.0000
# 3         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000

# %%
# showing the last 5 rows of data entries
df.tail()
# Out:
#      survived                                     name     sex   age
# 495         1  Mallet, Mrs. Albert (Antoinette Magnin)  female  24.0
# 496         0        Mangiavacchi, Mr. Serafino Emilio    male   NaN
# 497         0               Matthews, Mr. William John    male  30.0
# 498         0                Maybery, Mr. Frank Hubert    male  40.0
# 499         0                McCrae, Mr. Arthur Gordon    male  32.0

# %%
# showing sample 5 rows of the data entries
# the results change everytime the code is executed (random sample)
df.sample(5)
# Out:
#      survived                                         name   sex   age
# 234         0              Reuchlin, Jonkheer. John George  male  38.0
# 147         0                    Harrington, Mr. Charles H  male   NaN
# 243         0  Rosenshine, Mr. George ("Mr George Thorne")  male  46.0
# 460         0                 Jacobsohn, Mr. Sidney Samuel  male  42.0
# 346         0                   Botsford, Mr. William Hull  male  26.0

# %% [markdown]
# Observations:
# 1. All columns has complete fromats and appropriately typed
# 2. Sex column is categoricals and seems to contain two distinct values (female OR male), but will confirm later
# 3. Survived column is numerical type and apparently the binary value (0,1)
# 4. No obvious on the data (column name vs its entries), all seems good

# %%
df.info()
# Check the result
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  500 non-null    int64
#  1   name      500 non-null    object
#  2   sex       500 non-null    object
#  3   age       451 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# Observation:
# 1. Data contains 4 columns with 500 rows
# 2. There are 2 columns of categoricals (name and sex) and 2 columns of numericals (survived and age)
# 2. Only AGE column have missing values (49 missing data entries), they will be handled later
# 3. All dtypes seems OK (appropriate), given the corresponding column name. In order to Sex is naturally object.

# %% [markdown]
# # Statistical Summary

# %%
df.columns
# Analyze the statistical summary by the columns
# Out:
# Index(['survived', 'name', 'sex', 'age'], dtype='object')

# %%
# group column names based on type
# it will make our life easier onwards
categoricals = ['sex']

numericals = ['survived', 'age']

# %%
print("=== Passenger Survival ===")
print(df['survived'].value_counts())

# Pie chart for the survival distribution
survival_counts = df['survived'].value_counts()

# Plot pie chart with specified colors: green for survived, red for not survived
survival_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['green', 'blue'],
                         labels=['Survived', 'Not Survived'])
# Out:
# === Passenger Survival ===
# survived
# 1    270
# 0    230
# Name: count, dtype: int64
# <Axes: ylabel='count'>

# %%
print("=== Gender ===")
print(df['sex'].value_counts())

# Bar plot for the gender distribution of passengers
sex_counts = df['sex'].value_counts()

# Plot the bar chart to compare the number of males and females
sex_counts.plot(kind='bar', color=['#ADD8E6', '#F7CAC9'])  # #ADD8E6 for males (blue), #F7CAC9 for females (red)
# Out:
# === Gender ===
# sex
# male      288
# female    212
# Name: count, dtype: int64
# <Axes: xlabel='sex'>

# %%
# Statistical summary for the numeric column (age)
print("=== Passenger Age ===")
print(df['age'].describe())  # This gives the mean, std, min, max, and quartiles

# Creating the 'age_group' column based on age
bins = [0, 12, 18, 60, 100]
labels = ['Children', 'Teenagers', 'Adults', 'Elderly']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

# Displaying the distribution of passenger age groups
print("=== Passenger Age Groups ===")
print(df['age_group'].value_counts())

# Bar plot for the distribution of passenger age groups
sns.countplot(x='age_group', data=df, palette='Set1')
plt.title('Distribution of Passenger Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Passengers')
plt.show()
# Out:
# === Passenger Age ===
# count    451.000000
# mean      35.917775
# std       14.766454
# min        0.666700
# 25%       24.000000
# 50%       35.000000
# 75%       47.000000
# max       80.000000
# Name: age, dtype: float64
# === Passenger Age Groups ===
# age_group
# Adults       380
# Teenagers     29
# Elderly       24
# Children      18
# Name: count, dtype: int64
# <ipython-input-105-07c2ffa7ffc1>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='age_group', data=df, palette='Set1')

# %%
df.describe(include='all')
# Display all the data sets by grouping
# Out:
#           survived                            name   sex         age age_group
# count   500.000000                             500   500  451.000000       451
# unique         NaN                             499     2         NaN         4
# top            NaN  Eustis, Miss. Elizabeth Mussey  male         NaN    Adults
# freq           NaN                               2   288         NaN       380
# mean      0.540000                             NaN   NaN   35.917775       NaN
# std       0.498897                             NaN   NaN   14.766454       NaN
# min       0.000000                             NaN   NaN    0.666700       NaN
# 25%       0.000000                             NaN   NaN   24.000000       NaN
# 50%       1.000000                             NaN   NaN   35.000000       NaN
# 75%       1.000000                             NaN   NaN   47.000000       NaN
# max       1.000000                             NaN   NaN   80.000000       NaN

# %%
# syntax numerical statistical summary
df[numericals].describe()
# Out:
#          survived         age
# count  500.000000  451.000000
# mean     0.540000   35.917775
# std      0.498897   14.766454
# min      0.000000    0.666700
# 25%      0.000000   24.000000
# 50%      1.000000   35.000000
# 75%      1.000000   47.000000
# max      1.000000   80.000000

# %% [markdown]
# Observation:
#
#
# *   Overall, the minimum and maximum values make sense for each column
# *   Mean~ to 50% (Median) in AGE is somewhat symmetrical distribution (values of variables appear at regular frequencies and often the mean, median, and mode all occur at the same point)
# *   Survived column is boolean/binary column since the values is 1 or 0, no need to conclude its simmetricity. Only need to check balance level

# %%
# Syntax describe meethod on categorical data
df[categoricals].describe()
# Out:
#          sex
# count    500
# unique     2
# top     male
# freq     288

# %%
categoricals
# check the categoricals entries
# Out:
# ['sex']

# %%
# showing the precise value counts
# this code is especially useful if we have many categorical columns
for col in categoricals:
    print(f'Column: {col}')
    print(df[col].value_counts())
# Out:
# Column: sex
# sex
# male      288
# female    212
# Name: count, dtype: int64

# %%
for col in numericals:
  print(f'====={col}=====')
  print(df[col].value_counts(), '\n')

  # review the datasets by numericals
# Out:
# =====survived=====
# survived
# 1    270
# 0    230
# Name: count, dtype: int64
#
# =====age=====
# age
# 24.0000    23
# 30.0000    20
# 36.0000    19
# 18.0000    14
# 42.0000    14
# 45.0000    14
# 35.0000    14
# 22.0000    12
# 28.0000    12
# 23.0000    11
# 21.0000    11
# 31.0000    11
# 48.0000    11
# 25.0000    11
# 29.0000    10
# 54.0000    10
# 50.0000    10
# 34.0000    10
# 47.0000    10
# 39.0000     9
# 27.0000     9
# 33.0000     8
# 49.0000     8
# 38.0000     8
# 19.0000     8
# 40.0000     8
# 55.0000     8
# 32.0000     7
# 60.0000     7
# 17.0000     7
# 26.0000     7
# 44.0000     6
# 52.0000     6
# 37.0000     6
# 58.0000     6
# 64.0000     5
# 46.0000     5
# 57.0000     5
# 51.0000     5
# 16.0000     4
# 53.0000     4
# 56.0000     4
# 43.0000     4
# 62.0000     4
# 61.0000     4
# 1.0000      3
# 8.0000      3
# 63.0000     3
# 41.0000     3
# 15.0000     2
# 71.0000     2
# 20.0000     2
# 65.0000     2
# 4.0000      2
# 6.0000      2
# ...

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# # 1. Duplicate Handling

# %%
len(df)
# Count the data string
# Out:
# 500

# %%
len(df.drop_duplicates())
# Find the duplicates data in the string
# Out:
# 499

# %%
len(df.drop_duplicates()) / len(df)
# Analyze the percentage of duplicates data in datasets
# Out:
# 0.998

# %%
list(df.columns)
# Check the duplicates data by columns
# Out:
# ['survived', 'name', 'sex', 'age', 'age_group']

# %%
# Step 1 : Track the rows of duplicates data within the original row
duplicates = df[df.duplicated(keep=False)]

# %%
duplicates
# display the duplicates
# Out:
#      survived                            name     sex   age age_group
# 104         1  Eustis, Miss. Elizabeth Mussey  female  54.0    Adults
# 349         1  Eustis, Miss. Elizabeth Mussey  female  54.0    Adults

# %%
duplicates.groupby(list(df.columns)).size()
# Count the total of duplicates
# Out:
# <ipython-input-118-95d3a6b4ce58>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   duplicates.groupby(list(df.columns)).size()
# survived  name                            sex     age   age_group
# 1         Eustis, Miss. Elizabeth Mussey  female  54.0  Children     0
#                                                         Teenagers    0
#                                                         Adults       2
#                                                         Elderly      0
# dtype: int64

# %%
duplicates.groupby(list(df.columns)).size().reset_index(name='total duplicates')
# display total duplicates
# Out:
# <ipython-input-119-924d3386166b>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   duplicates.groupby(list(df.columns)).size().reset_index(name='total duplicates')
#    survived                            name     sex   age  age_group  \
# 0         1  Eustis, Miss. Elizabeth Mussey  female  54.0   Children
# 1         1  Eustis, Miss. Elizabeth Mussey  female  54.0  Teenagers
# 2         1  Eustis, Miss. Elizabeth Mussey  female  54.0     Adults
# 3         1  Eustis, Miss. Elizabeth Mussey  female  54.0    Elderly
#
#    total duplicates
# 0                 0
# 1                 0
# 2                 2
# 3                 0

# %%
# Handling Drop Duplicate
df = df.drop_duplicates()

# %%
len(df.drop_duplicates()) / len(df)
# review the percentage of total duplicates by total datasets
# Out:
# 1.0

# %% [markdown]
# Telah dihandling drop duplikat

# %% [markdown]
# # 2. Missing Values Handling

# %% [markdown]
# # Identiifying Missing Value

# %%
df.isna().sum()
# Count the missing values
# Out:
# survived      0
# name          0
# sex           0
# age          49
# age_group    49
# dtype: int64

# %%
df.isnull().sum()
# Identifying the total of missing values
# Out:
# survived      0
# name          0
# sex           0
# age          49
# age_group    49
# dtype: int64

# %% [markdown]
# Observation:
# - Only AGE column has missing values
# - There has 49 missing data entries of AGE column

# %%
for column in df.columns:
    print(f"========{column}==================")
    display(df[column].value_counts())
    print()
# display the sum of datasets by columns
# Out:
# ========survived==================
# survived
# 1    269
# 0    230
# Name: count, dtype: int64
# ========name==================
# name
# McCrae, Mr. Arthur Gordon                                                             1
# Allen, Miss. Elisabeth Walton                                                         1
# Allison, Master. Hudson Trevor                                                        1
# Lehmann, Miss. Bertha                                                                 1
# Laroche, Mrs. Joseph (Juliette Marie Louise Lafargue)                                 1
# Laroche, Mr. Joseph Philippe Lemercier                                                1
# Laroche, Miss. Simonne Marie Anne Andree                                              1
# Laroche, Miss. Louise                                                                 1
# Lamb, Mr. John Joseph                                                                 1
# ...

# %% [markdown]
# Observation:
#
# *   There has 269 survivors and the rest is dead (230)
# *   The most gender of in Titanic is male (288) and the rest is female (211)
# *   The most of the Titanic's passengers AGE in range at 24-30 years old

# %%
total_rows = len(df)
total_rows
# display the actual datasets
# Out:
# 499

# %%
df.columns
# Handling the missing values by analyzing each column
# Out:
# Index(['survived', 'name', 'sex', 'age', 'age_group'], dtype='object')

# %%
# percentage version
total_rows = len(df)

# Counts and display the missing values on each other columns
for column in df.columns:
    missing_count = df[column].isna().sum()
    missing_percentage = (missing_count / total_rows) * 100
    print(f"Column '{column}' has {missing_count} missing values ({missing_percentage:.2f}%)") # .2f means 2 decimal
# Out:
# Column 'survived' has 0 missing values (0.00%)
# Column 'name' has 0 missing values (0.00%)
# Column 'sex' has 0 missing values (0.00%)
# Column 'age' has 49 missing values (9.82%)
# Column 'age_group' has 49 missing values (9.82%)

# %% [markdown]
# The percentage of missing values below 20% so we handle numerically with median, categorical with mode. But the categorical data type does not have missing values, namely sex.

# %% [markdown]
# # Handling the Missing Values

# %%
df.info()
# Review the missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   survived   499 non-null    int64
#  1   name       499 non-null    object
#  2   sex        499 non-null    object
#  3   age        450 non-null    float64
#  4   age_group  450 non-null    category
# dtypes: category(1), float64(1), int64(1), object(2)
# memory usage: 20.2+ KB

# %%
df['sex'].dtype
# find the type of value of "sex"
# Out:
# dtype('O')

# %%
df['sex'].mode()[0]
# find the mode of categoricals data
# Out:
# 'male'

# %%
df['survived'].median()
# find the median of numerical data
# Out:
# 1.0

# %%
# Handling missing value for EDA, without splitting
for column in df.columns:
    if df[column].dtype == 'object':
      # if the column type is categoricals, filled it with mode
        df[column].fillna(df[column].mode()[0], inplace=True)
    else: # Through the data type is only numericals, use the else:
          # if the column type is numericals, filled it with median
        df[column].fillna(df[column].median(), inplace=True)
# Out:
# <ipython-input-132-fd20ffd0f4bc>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(df[column].median(), inplace=True)
# <ipython-input-132-fd20ffd0f4bc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column].fillna(df[column].median(), inplace=True)
# ...

# %%
df.isna().sum()
# showing the result of handling missing data

# %%
df.info()
# Review the clear data

# %% [markdown]
# Success removing NULL values!

# %% [markdown]
# # Results Analysis Visualization

# %%
# Set the style of seaborn
sns.set(style="whitegrid")

# 1. Age Distribution Based on Passenger Status
plt.figure(figsize=(10, 6))
sns.countplot(x='survived', hue='age_group', data=df, palette='Set1')
plt.title('Age Group Distribution Based on Passenger Status')
plt.xlabel('Passenger Status (0 = Not Survived, 1 = Survived)')
plt.ylabel('Number of Passengers')
plt.legend(title='Age Group')
plt.show()

# %%
# 2. Gender Distribution Based on Passenger Status
plt.figure(figsize=(8, 5))
sns.countplot(x='sex', hue='survived', data=df, palette={0: 'blue', 1: 'brown'})
plt.title('Distribution of Gender Based on Passenger Status')
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.legend(title='Passenger Status', labels=['Not Survived', 'Survived'])
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
plt.show()

# %%
# Standardize 'sex' column to ensure it's either 'Male' or 'Female'
df['sex'] = df['sex'].apply(lambda x: 'Female' if x == 'female' else 'Male' if x == 'male' else x)

# Creating a crosstab to calculate the survival proportions based on age group and gender
crosstab = pd.crosstab([df['age_group'], df['sex']], df['survived'], normalize='index')

# Renaming the index for better descriptiveness (male/female)
crosstab.index = [(age, 'Female') if sex == 'Female' else (age, 'Male')
                  for age, sex in crosstab.index]

# Visualization using heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(crosstab, annot=True, cmap='YlGnBu', fmt='.2f')
plt.title('Survival Proportions Based on Age Group and Gender')
plt.xlabel('Passenger Status (0 = Not Survived, 1 = Survived)')
plt.ylabel('Age Group & Gender')
plt.show()
# Out:
# <ipython-input-135-ec26d1f21ee6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex'] = df['sex'].apply(lambda x: 'Female' if x == 'female' else 'Male' if x == 'male' else x)

# %% [markdown]
# ## THIS IS THE END OF THE SESSION. THANKYOU!
